# %%
import yt
import numpy as np
import pandas as pd
from galexquared.class_methods import load_ftable

# %%
table = load_ftable("GEAR_equivalence.dat"); table
# Out:
#      snapshot  snapnum            snapname   redshift
# 0           0        0  snapshot_0000.hdf5  15.000000
# 1           1        1  snapshot_0001.hdf5  14.951583
# 2           2        2  snapshot_0002.hdf5  14.903312
# 3           3        3  snapshot_0003.hdf5  14.855187
# 4           4        4  snapshot_0004.hdf5  14.807207
# ..        ...      ...                 ...        ...
# 836       836      841  snapshot_0841.hdf5   0.312953
# 837       837      842  snapshot_0842.hdf5   0.308980
# 838       838      843  snapshot_0843.hdf5   0.305018
# 839       839      844  snapshot_0844.hdf5   0.301069
# 840       840      845  snapshot_0845.hdf5   0.297132
#
# [841 rows x 4 columns]

# %%
merger = pd.read_csv("merger_trees_csv/fullGEAR_HostTree.csv")

# %%
pdir = "/media/asier/T7/GEAR/"
table["redshift_RCT"] = pd.Series()
table["time"] = pd.Series()

for index, line in table.iterrows():
    try:
        ds = yt.load(pdir + line["snapname"])
        time = ds.current_time.to("Gyr").value
    except:
        print(f"Failed with {line['snapname']}")
        time = np.nan

    z_rct = merger[merger["Snapshot"] == line["snapshot"]]["Redshift"].values[0]

    table.loc[index, "redshift_RCT"] = z_rct
    table.loc[index, "time"] = time
# Out:
# yt : [INFO     ] 2025-03-24 11:16:26,805 Calculating time from 6.250e-02 to be 8.778e+15 seconds
# yt : [INFO     ] 2025-03-24 11:16:26,806 Assuming length units are in kpc/h (comoving)
# yt : [INFO     ] 2025-03-24 11:16:26,855 Parameters: current_time              = 8778308115244959.0 s
# yt : [INFO     ] 2025-03-24 11:16:26,856 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-03-24 11:16:26,856 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-24 11:16:26,856 Parameters: domain_right_edge         = [60000. 60000. 60000.]
# yt : [INFO     ] 2025-03-24 11:16:26,857 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2025-03-24 11:16:26,857 Parameters: current_redshift          = 15.00000000000237
# yt : [INFO     ] 2025-03-24 11:16:26,857 Parameters: omega_lambda              = 0.728
# yt : [INFO     ] 2025-03-24 11:16:26,857 Parameters: omega_matter              = 0.272
# ...

# %%
table
# Out:
#      snapshot  snapnum            snapname   redshift redshift_RCT  \
# 0           0        0  snapshot_0000.hdf5  15.000000         15.0
# 1           1        1  snapshot_0001.hdf5  14.951583    14.951509
# 2           2        2  snapshot_0002.hdf5  14.903312    14.903307
# 3           3        3  snapshot_0003.hdf5  14.855187    14.855399
# 4           4        4  snapshot_0004.hdf5  14.807207    14.807778
# ..        ...      ...                 ...        ...          ...
# 836       836      841  snapshot_0841.hdf5   0.312953     0.312956
# 837       837      842  snapshot_0842.hdf5   0.308980     0.308986
# 838       838      843  snapshot_0843.hdf5   0.305018     0.305023
# 839       839      844  snapshot_0844.hdf5   0.301069     0.301067
# 840       840      845  snapshot_0845.hdf5   0.297132     0.297135
#
#                     time
# 0    0.27816779841448525
# 1     0.2794349554864873
# 2                    NaN
# 3      0.281986605328845
# 4                    NaN
# ...

# %%
table.to_csv("GEAR_equivalence.csv", index=False)

# %%
from astropy.table import Table

# %%
t = Table.read("GEAR_equivalence.csv", format="csv")

# %%
t.write("GEAR_equivalence.dat", format="ascii.fixed_width", delimiter="\t")

# %%
thin = pd.read_csv("thinnedGEAR_equivalence.csv")

# %%
t[np.isin(t["snapname"],thin["snapname"].values)].write("thinnedGEAR_equivalence.dat", format="ascii.fixed_width", delimiter="\t")

# %%
yt.load("/media/asier/T7/GEAR/snapshot_0170.hdf5)

# %%
t[np.isin(t["snapname"],thin["snapname"].values)]
# Out:
# <Table length=337>
# snapshot snapnum      snapname      ...    redshift_RCT            time
#  int64    int64        str18        ...      float64             float64
# -------- ------- ------------------ ... ------------------ -------------------
#        0       0 snapshot_0000.hdf5 ...               15.0 0.27816779841448525
#        3       3 snapshot_0003.hdf5 ... 14.855399131774902   0.281986605328845
#        5       5 snapshot_0005.hdf5 ... 14.760440826416016 0.28456154494432334
#        7       7 snapshot_0007.hdf5 ... 14.664159774780272  0.2871599866158424
#       10      10 snapshot_0010.hdf5 ...   14.5231294631958   0.291102184593297
#       13      13 snapshot_0013.hdf5 ...  14.38224983215332 0.29509847580301607
#       15      15 snapshot_0015.hdf5 ...  14.28818130493164 0.29779308732570303
#       17      17 snapshot_0017.hdf5 ...   14.1975679397583 0.30051229157005116
#       20      20 snapshot_0020.hdf5 ... 14.057973861694336 0.30463770007755675
# ...

# %%
nt = pd.read_csv("selected_halos_GEAR/New_tree.csv"); nt
# Out:
# /tmp/ipykernel_2887633/2767125305.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   nt = pd.read_csv("selected_halos_GEAR/New_tree.csv"); nt
#          Unnamed: 0.1  Halo_ID  Snapshot  Redshift       Time         uid  \
# 0                   0   1727.0       336  0.297135  10.396805  14578957.0
# 1                   2   1786.0       335  0.305023  10.323493  14553178.0
# 2                   3   1803.0       334  0.316933  10.214212  14511174.0
# 3                   8   1435.0       333  0.328957  10.105573  14468197.0
# 4                  10   1772.0       332  0.337041  10.033459  14438074.0
# ...               ...      ...       ...       ...        ...         ...
# 3474682            10      NaN       239  1.733828   3.857633         NaN
# 3474683            11      NaN       240  1.709085   3.908451         NaN
# 3474684            12      NaN       241  1.684565   3.959884         NaN
# ...

# %%
tt = pd.read_csv("merger_trees_csv/thinnedGEAR_HostTree.csv"); tt["Snapshot"].unique()
# Out:
# array([840., 838., 835., 832., 830., 828., 825., 822., 820., 818., 815.,
#        812., 809., 806., 803., 801., 799., 793., 791., 796., 789., 786.,
#        783., 781., 779., 776., 773., 771., 769., 766., 763., 761., 759.,
#        756., 753., 751., 749., 746., 743., 741., 739., 736., 733., 729.,
#        731., 726., 723., 721., 719., 716., 701., 699., 713., 711., 696.,
#        703., 693., 706., 709., 691., 689., 686., 683., 674., 672., 676.,
#        681., 679., 669., 666., 664., 662., 659., 656., 654., 652., 649.,
#        646., 644., 642., 639., 636., 634., 632., 629., 626., 624., 622.,
#        609., 606., 604., 619., 614., 616., 612., 602., 599., 596., 594.,
#        592., 589., 579., 576., 586., 574., 584., 572., 582., 569., 566.,
#        564., 562., 559., 556., 554., 552., 549., 546., 545., 543., 540.,
#        537., 535., 533., 530., 527., 525., 523., 520., 517., 515., 513.,
#        510., 507., 505., 503., 500., 497., 495., 493., 490., 487., 485.,
# ...

# %%
thin["snapshot"] = thin.index

# %%
thin
# Out:
#      snapshot  snapnum            snapname   redshift
# 0           0        0  snapshot_0000.hdf5  15.000000
# 1           1        3  snapshot_0003.hdf5  14.855187
# 2           2        5  snapshot_0005.hdf5  14.759373
# 3           3        7  snapshot_0007.hdf5  14.664139
# 4           4       10  snapshot_0010.hdf5  14.522366
# ..        ...      ...                 ...        ...
# 332       332      835  snapshot_0835.hdf5   0.337046
# 333       333      837  snapshot_0837.hdf5   0.328966
# 334       334      840  snapshot_0840.hdf5   0.316938
# 335       335      843  snapshot_0843.hdf5   0.305018
# 336       336      845  snapshot_0845.hdf5   0.297132
#
# [337 rows x 4 columns]

# %%
pd.options.display.max_rows = 1000

# %%
xyz = pd.read_csv("merger_trees_csv/ART_HostTree.csv").sort_values("Snapshot"); xyz
# Out:
#      Halo_ID  Snapshot   Redshift       Time        uid   desc_uid  \
# 380     96.0       0.0  14.984654   0.278569        1.0      609.0
# 379     91.0       1.0  14.845349   0.282250      609.0     1274.0
# 378     83.0       2.0  14.705983   0.286014     1274.0     1980.0
# 377    129.0       3.0  14.595757   0.289051     1980.0     2735.0
# 376    130.0       4.0  14.458340   0.292913     2735.0     3567.0
# 375    149.0       5.0  14.320974   0.296860     3567.0     4447.0
# 374    149.0       6.0  14.211440   0.300072     4447.0     5333.0
# 373    136.0       7.0  14.073862   0.304188     5333.0     6244.0
# 372    146.0       8.0  13.992504   0.306667     6244.0     7205.0
# 371    154.0       9.0  13.965578   0.307494     7205.0     8285.0
# 370    150.0      10.0  13.830194   0.311714     8285.0     9513.0
# 369    163.0      11.0  13.723204   0.315117     9513.0    10833.0
# 368    144.0      12.0  13.590020   0.319440    10833.0    12241.0
# ...

# %%
ds = yt.load("/media/asier/EXTERNAL_USBA/Cosmo_v18/10MpcBox_csf512_03498.d")
# Out:
# yt : [INFO     ] 2025-03-24 16:31:43,240 discovered particle_header:/media/asier/EXTERNAL_USBA/Cosmo_v18/PMcrd_03498.DAT
# yt : [INFO     ] 2025-03-24 16:31:43,241 discovered particle_data:/media/asier/EXTERNAL_USBA/Cosmo_v18/PMcrs0_03498.DAT
# yt : [INFO     ] 2025-03-24 16:31:43,241 discovered particle_stars:/media/asier/EXTERNAL_USBA/Cosmo_v18/stars_03498.dat
# yt : [INFO     ] 2025-03-24 16:31:43,244 Using root level of 14
# yt : [INFO     ] 2025-03-24 16:31:43,245 Discovered 7 species of particles
# yt : [INFO     ] 2025-03-24 16:31:43,245 Particle populations:  13330288   1432362    598765    314898    206550   2064487   1787528
# yt : [INFO     ] 2025-03-24 16:31:43,270 Max level is 13
# yt : [INFO     ] 2025-03-24 16:31:43,309 Parameters: current_time              = 7.429946223114462 Gyr
# yt : [INFO     ] 2025-03-24 16:31:43,309 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2025-03-24 16:31:43,309 Parameters: domain_left_edge          = [0. 0. 0.]
# ...

# %%
load_ftable("ART_equivalence.dat")
# Out:
#      snapshot  snapnum                 snapname  redshift_snap  scale_factor  \
# 0          72     2002  10MpcBox_csf512_02002.d       8.252862      0.108075
# 1          73     2006  10MpcBox_csf512_02006.d       8.167741      0.109078
# 2          74     2009  10MpcBox_csf512_02009.d       8.104156      0.109840
# 3          75     2013  10MpcBox_csf512_02013.d       8.019716      0.110868
# 4          76     2014  10MpcBox_csf512_02014.d       7.998667      0.111128
# 5          77     2016  10MpcBox_csf512_02016.d       7.956642      0.111649
# 6          78     2020  10MpcBox_csf512_02020.d       7.872883      0.112703
# 7          79     2023  10MpcBox_csf512_02023.d       7.810319      0.113503
# 8          80     2027  10MpcBox_csf512_02027.d       7.727241      0.114584
# 9          81     2030  10MpcBox_csf512_02030.d       7.665188      0.115404
# 10         82     2034  10MpcBox_csf512_02034.d       7.582790      0.116512
# ...

# %%
1/(1-0.000114 	)
# Out:
# 1.0001140129974817

# %%
xyz = pd.read_csv("merger_trees_csv/thinnedGEAR_HostTree.csv").sort_values("Snapshot"); xyz
# Out:
#      Halo_ID  Snapshot   Redshift       Time         uid    desc_uid  \
# 336     18.0       0.0  15.000000   0.278169        38.0      2123.0
# 335     28.0       3.0  14.855399   0.281982      6447.0      8741.0
# 334     72.0       5.0  14.760441   0.284533     11118.0     13558.0
# 333     30.0       7.0  14.664160   0.287160     16071.0     18613.0
# 332    106.0      10.0  14.523129   0.291082     23802.0     26403.0
# ..       ...       ...        ...        ...         ...         ...
# 4     1772.0     830.0   0.337041  10.033459  14438074.0  14452919.0
# 3     1435.0     832.0   0.328957  10.105573  14468197.0  14482899.0
# 2     1803.0     835.0   0.316933  10.214212  14511174.0  14525142.0
# 1     1786.0     838.0   0.305023  10.323493  14553178.0  14566431.0
# 0     1727.0     840.0   0.297135  10.396805  14578957.0        -1.0
#
#              mass  num_prog  virial_radius  scale_radius  ...   c_to_a  \
# ...

# %%
xyz = xyz.reset_index(drop=True); xyz
# Out:
#      Halo_ID  Snapshot   Redshift       Time         uid    desc_uid  \
# 0       18.0       0.0  15.000000   0.278169        38.0      2123.0
# 1       28.0       3.0  14.855399   0.281982      6447.0      8741.0
# 2       72.0       5.0  14.760441   0.284533     11118.0     13558.0
# 3       30.0       7.0  14.664160   0.287160     16071.0     18613.0
# 4      106.0      10.0  14.523129   0.291082     23802.0     26403.0
# ..       ...       ...        ...        ...         ...         ...
# 332   1772.0     830.0   0.337041  10.033459  14438074.0  14452919.0
# 333   1435.0     832.0   0.328957  10.105573  14468197.0  14482899.0
# 334   1803.0     835.0   0.316933  10.214212  14511174.0  14525142.0
# 335   1786.0     838.0   0.305023  10.323493  14553178.0  14566431.0
# 336   1727.0     840.0   0.297135  10.396805  14578957.0        -1.0
#
#              mass  num_prog  virial_radius  scale_radius  ...   c_to_a  \
# ...

# %%
nt = pd.read_csv("selected_halos_GEAR/New_tree.csv")
# Out:
# /tmp/ipykernel_3008024/4160909213.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   nt = pd.read_csv("selected_halos_GEAR/New_tree.csv")

# %%
nt = nt.drop("Unnamed: 0.1", axis=1)

# %%
nt
# Out:
#          Halo_ID  Snapshot  Redshift       Time         uid    desc_uid  \
# 0         1727.0       336  0.297135  10.396805  14578957.0        -1.0
# 1         1786.0       335  0.305023  10.323493  14553178.0  14566431.0
# 2         1803.0       334  0.316933  10.214212  14511174.0  14525142.0
# 3         1435.0       333  0.328957  10.105573  14468197.0  14482899.0
# 4         1772.0       332  0.337041  10.033459  14438074.0  14452919.0
# ...          ...       ...       ...        ...         ...         ...
# 3474682      NaN       239  1.733828   3.857633         NaN         NaN
# 3474683      NaN       240  1.709085   3.908451         NaN         NaN
# 3474684      NaN       241  1.684565   3.959884         NaN         NaN
# 3474685      NaN       242  1.668342   3.994516         NaN         NaN
# 3474686      NaN       243  1.652217   4.029426         NaN         NaN
#
#                  mass  num_prog  virial_radius  scale_radius  ...  \
# ...

# %%
for index, line in xyz.sort_values("Snapshot", ascending=False).iterrows():
    ss_index = nt[nt["Snapshot"] == index].index

    nt.loc[ss_index, "Snapshot"] = line["Snapshot"]
    nt.loc[ss_index, "Time"] = line["Time"]
    nt.loc[ss_index, "Redshift"] = line["Redshift"]

# %%
np.sort(nt["Snapshot"].unique()) == np.sort(xyz["Snapshot"].unique())
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
nt[nt["Sub_tree_id"] == 899].sort_values("Snapshot", ascending=False)
# Out:
#          Halo_ID  Snapshot   Redshift      Time        uid   desc_uid  \
# 3474568      NaN       582   1.852335  3.628428        NaN        NaN
# 3474567      NaN       579   1.878361  3.581037        NaN        NaN
# 3474566      NaN       576   1.904697  3.534093        NaN        NaN
# 3474565      NaN       574   1.922353  3.503178        NaN        NaN
# 3474564      NaN       572   1.940052  3.472626        NaN        NaN
# 3474563      NaN       569   1.966919  3.427069        NaN        NaN
# 3474562      NaN       566   1.994012  3.382105        NaN        NaN
# 3474561      NaN       564   2.003093  3.367247        NaN        NaN
# 3474560      NaN       562   2.021422  3.337582        NaN        NaN
# 3474559      NaN       559   2.048966  3.293794        NaN        NaN
# 3474558      NaN       556   2.076828  3.250445        NaN        NaN
# 3474557      NaN       554   2.095496  3.221918        NaN        NaN
# ...

# %%
nt.to_csv("GEAR_NewTree.csv", index=False)

# %%
xyz.sort_values("Snapshot", ascending=True)[:582]
# Out:
#      Halo_ID  Snapshot   Redshift       Time         uid    desc_uid  \
# 0       18.0       0.0  15.000000   0.278169        38.0      2123.0
# 1       28.0       3.0  14.855399   0.281982      6447.0      8741.0
# 2       72.0       5.0  14.760441   0.284533     11118.0     13558.0
# 3       30.0       7.0  14.664160   0.287160     16071.0     18613.0
# 4      106.0      10.0  14.523129   0.291082     23802.0     26403.0
# 5       90.0      13.0  14.382250   0.295089     31642.0     34301.0
# 6      131.0      15.0  14.288181   0.297816     37133.0     40050.0
# 7      144.0      17.0  14.197568   0.300482     43027.0     46069.0
# 8      126.0      20.0  14.057974   0.304669     52278.0     55427.0
# 9      122.0      23.0  13.967820   0.307426     61799.0     65054.0
# 10     121.0      25.0  13.876524   0.310259     68528.0     72063.0
# 11     128.0      27.0  13.788524   0.313032     75647.0     79239.0
# 12     133.0      30.0  13.654161   0.317345     86516.0     90168.0
# ...

# %%
nt = pd.read_csv("selected_halos_GEAR/New_tree.csv")
# Out:
# /tmp/ipykernel_3008024/4160909213.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   nt = pd.read_csv("selected_halos_GEAR/New_tree.csv")

# %%
nt[nt["Sub_tree_id"] == 899].sort_values("Snapshot", ascending=False)
# Out:
#          Unnamed: 0.1  Halo_ID  Snapshot   Redshift      Time        uid  \
# 3474568            27      NaN       233   1.852319  3.628448        NaN
# 3474567            26      NaN       232   1.878371  3.581009        NaN
# 3474566            25      NaN       231   1.904660  3.534149        NaN
# 3474565            24      NaN       230   1.922320  3.503227        NaN
# 3474564            23      NaN       229   1.940087  3.472558        NaN
# 3474563            22      NaN       228   1.966940  3.427025        NaN
# 3474562            21      NaN       227   1.994039  3.382052        NaN
# 3474561            20      NaN       226   2.003126  3.367185        NaN
# 3474560            19      NaN       225   2.021385  3.337633        NaN
# 3474559            18      NaN       224   2.048981  3.293763        NaN
# 3474558            17      NaN       223   2.076828  3.250437        NaN
# 3474557            16      NaN       222   2.095535  3.221851        NaN
# ...

# %%
pd.options.display.max_rows = 10000

# %%
for snap in xyz["Snapshot"].unique():
    time, red = tuple(xyz[xyz["Snapshot"] == snap][["Time", "Redshift"]].values[0])

    indexes = nt[nt["Snapshot"] == snap].index
    nt.loc[indexes, "Time"] = time
    nt.loc[indexes, "Redshift"] = red

# %%
nt.to_csv("ART_NewTree.csv", index=False)

# %%
ntt = pd.read_csv("selected_halos_ART/New_tree.csv")
# Out:
# /tmp/ipykernel_2887633/2395319051.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   ntt = pd.read_csv("selected_halos_ART/New_tree.csv")
